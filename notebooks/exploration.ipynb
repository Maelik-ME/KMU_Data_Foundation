# %%
from src.io import load_csv
from src.cleaning import standardize_column_names
from src.io import save_csv

df_raw = load_csv("data/raw/sales_raw.csv")
df_raw

df_clean = standardize_column_names(df_raw)
df_clean

save_csv(df_clean, "data/processed/sales_processed.csv")
